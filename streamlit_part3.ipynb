# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

url= 'https://raw.githubusercontent.com/mwaskom/seaborn-data/refs/heads/master/flights.csv'
df= pd.read_csv(url)

corr= True

if corr:
    df_corr= df.corr(numeric_only= True)

fig, ax= plt.subplots(figsize= (10, 6))
sns.heatmap(df_corr, annot= True)
fig.show()
# Out:
# C:\Users\paulc\AppData\Local\Temp\ipykernel_32620\3647613730.py:16: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
import os
import pandas as pd

# Afficher le répertoire de travail actuel
print("Le fichier sera enregistré ici :")
print(os.getcwd())

data= {
    'name': 'Paul',
    'password': 'WCS2026',
    'email' : 'paul@gmail.com',
    'failed_login_attemps': 0,
    'logged_in': False,
    'role': 'admin'
    }

df= pd.DataFrame()

df.to_csv('accounts.csv', index= False)

# Afficher le chemin complet du fichier créé
print(f"\nFichier créé : {os.path.join(os.getcwd(), 'accounts.csv')}")
# Out:
# Le fichier sera enregistré ici :
# c:\Users\paulc\AppData\Local\Programs\Microsoft VS Code
#
# Fichier créé : c:\Users\paulc\AppData\Local\Programs\Microsoft VS Code\accounts.csv
